# %% [markdown]
# # Setup

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg
# !pip3 install --upgrade minerl
# !pip3 install pyvirtualdisplay
# !pip3 install pytorch
# !pip3 install -U colabgymrender

# %%
# !java -version
# Out:
# openjdk version "1.8.0_292"
# OpenJDK Runtime Environment (build 1.8.0_292-8u292-b10-0ubuntu1~18.04-b10)
# OpenJDK 64-Bit Server VM (build 25.292-b10, mixed mode)

# %% [markdown]
# # Download the data and code

# %%
# %env MINERL_DATA_ROOT=/content/data/

# !python3 -m minerl.data.download --environment "MineRLBasaltFindCave-v0"
# !ls $MINERL_DATA_ROOT
# Out:
# env: MINERL_DATA_ROOT=/content/data/
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'minerl.data.download' found in sys.modules after import of package 'minerl.data', but prior to execution of 'minerl.data.download'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2021-09-09 02:04:58 175781c86888 __main__[6147] INFO Downloading dataset for MineRLBasaltFindCave-v0 to /content/data/
# 2021-09-09 02:04:58 175781c86888 __main__[6147] INFO Starting download ...
# 2021-09-09 02:04:58 175781c86888 root[6147] DEBUG Choosing mirror ...
# 2021-09-09 02:04:58 175781c86888 root[6147] WARNING Unused mirror https://minerl-europe.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar returned status code 403
# 2021-09-09 02:04:59 175781c86888 root[6147] DEBUG Picked https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar ping=386.42ms
# 2021-09-09 02:04:59 175781c86888 root[6147] DEBUG Starting download at 0.0MB
# 2021-09-09 02:04:59 175781c86888 root[6147] DEBUG File size is 287.7MB
# Download: https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar: 100% 287.0/287.744 [00:10<00:00, 21.79MB/s]2021-09-09 02:05:09 175781c86888 root[6147] INFO Success - downloaded /content/data/download/v4/MineRLBasaltFindCave-v0.tar
# 2021-09-09 02:05:09 175781c86888 root[6147] INFO Extracting downloaded files - this may take some time
# Download: https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar: 100% 288.0/287.744 [00:10<00:00, 27.15MB/s]
# 2021-09-09 02:05:10 175781c86888 root[6147] INFO Success - extracted files to /content/data/
# download  MineRLBasaltFindCave-v0  VERSION

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/basalt-competition
# !pwd
# !ls $MINERL_DATA_ROOT
# Out:
# /content/gdrive/MyDrive/basalt-competition
# /content/gdrive/MyDrive/basalt-competition
# download  MineRLBasaltFindCave-v0  VERSION

# %% [markdown]
# # Run Training

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# !python train_submission_code.py --train-critic-false --debug-env

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# !python train_submission_code.py --preprocess-false --train-critic-false
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#
# 2021-09-09 03:14:25 175781c86888 minerl.env.malmo.instance.94ccc8[7593] ERROR [03:14:25] [Thread-10/WARN]: ERROR MESSAGE:
# 2021-09-09 03:14:25 175781c86888 minerl.env.malmo.instance.94ccc8[7593] WARNING [03:14:25] [Thread-10/WARN]: STACK TRACE:
# 2021-09-09 03:14:25 175781c86888 minerl.env.malmo.instance.94ccc8[7593] ERROR [03:14:25] [Sound Library Loader/WARN]: ERROR MESSAGE:
# 2021-09-09 03:14:31 175781c86888 minerl.env.malmo.instance.94ccc8[7593] WARNING [03:14:31] [Client thread/WARN]: Skipping bad option: lastServer:
# 2021-09-09 03:14:33 175781c86888 minerl.env.malmo.instance.94ccc8[7593] INFO Minecraft process ready
# 2021-09-09 03:14:33 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# 2021-09-09 03:14:33 175781c86888 minerl.env.malmo[7593] INFO Logging output of Minecraft to ./logs/mc_1434.log
# 2021-09-09 03:15:13 175781c86888 minerl.env.malmo.instance.94ccc8[7593] INFO [03:15:13] [Client thread/INFO]: [STDOUT]: [LOGTOPY] On Mac OSX Catalina make sure to install this OpenJDK 1.8.0_152-release-1056-b12, this prevents the NSDragRegions crash
# Training Starting
# Threw Snowball at step 18
# Termination reward: -0.88
# Threw Snowball at step 19
# Termination reward: -0.85
# Threw Snowball at step 27
# Termination reward: -0.92
# Threw Snowball at step 29
# Termination reward: -0.89
# Trajectory completed at step 31
# 2021-09-09 03:15:36 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# Threw Snowball at step 35
# Termination reward: -0.94
# Trajectory completed at step 48
# 2021-09-09 03:17:10 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# Threw Snowball at step 79
# Termination reward: -0.95
# Trajectory completed at step 92
# 2021-09-09 03:19:46 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# Iteration 100. Loss: 2.63, 0.27 it/s
# Iteration 200. Loss: 3.10, 0.39 it/s
# Iteration 300. Loss: 2.90, 0.39 it/s
# Iteration 400. Loss: 2.89, 0.39 it/s
# Iteration 500. Loss: 2.82, 0.39 it/s
# Threw Snowball at step 522
# Termination reward: -0.85
# Threw Snowball at step 526
# Termination reward: -0.66
# Trajectory completed at step 535
# 2021-09-09 03:39:30 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# Iteration 600. Loss: 2.77, 0.34 it/s
# Threw Snowball at step 622
# Termination reward: -0.87
# Trajectory completed at step 635
# 2021-09-09 03:44:25 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# Threw Snowball at step 653
# Termination reward: -0.89
# Trajectory completed at step 666
# 2021-09-09 03:46:28 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# Iteration 700. Loss: 2.58, 0.30 it/s
# Threw Snowball at step 709
# Termination reward: -0.88
# Trajectory completed at step 722
# 2021-09-09 03:49:27 175781c86888 minerl.env._multiagent[7593] INFO Attempting to quit: Malmo[None:94ccc8, proc=7604, addr=localhost:10434, locked=True]
# 2021-09-09 03:49:27 175781c86888 minerl.env.malmo.instance.94ccc8[7593] ERROR [03:49:27] [Client thread/INFO]: [STDOUT]: STATE ERROR - multiple states in the queue.
# 2021-09-09 03:49:27 175781c86888 minerl.env.malmo.instance.94ccc8[7593] WARNING [03:49:27] [Server thread/WARN]: Can't keep up! Did the system time change, or is the server overloaded? Running 52ms behind, skipping 1 tick(s)
# 2021-09-09 03:49:27 175781c86888 minerl.env.malmo.instance.94ccc8[7593] ERROR [03:49:27] [Client thread/INFO]: [STDOUT]: STATE ERROR - multiple states in the queue.
# Iteration 800. Loss: 2.53, 0.35 it/s
# Iteration 900. Loss: 2.42, 0.39 it/s
# Iteration 1000. Loss: 2.29, 0.40 it/s
# Iteration 1100. Loss: 2.32, 0.40 it/s
# Traceback (most recent call last):
#   File "train_submission_code.py", line 114, in <module>
#     main()
#   File "train_submission_code.py", line 107, in main
#     bc_agent.train(env, run)
#   File "/content/gdrive/My Drive/basalt-competition/agents/soft_q.py", line 91, in train
#     replay_buffer.sample_replay())
#   File "/content/gdrive/My Drive/basalt-competition/agents/soft_q.py", line 158, in train_one_batch
#     objective.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/_tensor.py", line 255, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py", line 149, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt
# 2021-09-09 04:07:39 175781c86888 minerl.env.malmo[7593] ERROR Attempted to send kill command to minecraft process and failed with exception [Errno 111] Connection refused
# 2021-09-09 04:07:39 175781c86888 process_watcher[7593] INFO About to reap process tree of 7604:launchClient.sh: i zombie, owner 7593, printing process tree status in termination order:
# 2021-09-09 04:07:39 175781c86888 process_watcher[7593] INFO 	-7604:launchClient.sh: i zombie, owner 7593
# 2021-09-09 04:07:39 175781c86888 process_watcher[7593] INFO Trying to SIGTERM 7604:launchClient.sh: i zombie, owner 7593
# 2021-09-09 04:07:39 175781c86888 process_watcher[7593] INFO Process psutil.Popen(pid=7604, name='launchClient.sh', status='terminated', exitcode=0, started='03:13:27') terminated with exit code 0

# %% [markdown]
# # Testing Subcomponents
