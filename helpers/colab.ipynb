# %% [markdown]
# # Setup

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg
# !pip3 install --upgrade minerl
# !pip3 install pyvirtualdisplay
# !pip3 install pytorch
# !pip3 install -U colabgymrender

# %%
# !java -version

# %% [markdown]
# # Download the data and code

# %%
# %env MINERL_DATA_ROOT=/content/data/

# !python3 -m minerl.data.download --environment "MineRLBasaltFindCave-v0"
# !ls $MINERL_DATA_ROOT

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# %cd /content/gdrive/MyDrive/basalt-drex
# !pwd
# !ls $MINERL_DATA_ROOT
# Out:
# /content/gdrive/MyDrive/basalt-drex
# /content/gdrive/MyDrive/basalt-drex
# download  MineRLBasaltFindCave-v0  VERSION

# %% [markdown]
# # Run Training

# %%
# !python train_submission_code.py
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 2021-09-01 00:06:20 c8110a2307f1 minerl.data.data_pipeline[6848] DEBUG Loading from file /content/data/MineRLBasaltFindCave-v0/v3_accomplished_pattypan_squash_ghost-6_765-1145
# 100% 344/344 [00:00<00:00, 2395.09it/s]
# Traceback (most recent call last):
#   File "train_submission_code.py", line 69, in <module>
#     main()
#   File "train_submission_code.py", line 52, in main
#     bc_agent = BCAgent(agent_name, device=th.device('cuda'))
#   File "/content/gdrive/My Drive/basalt-drex/agents/bc.py", line 16, in __init__
#     self.model = BC().to(device)
# TypeError: __init__() missing 1 required positional argument: 'inventory_dim'
