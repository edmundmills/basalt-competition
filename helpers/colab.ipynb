# %% [markdown]
# # Setup

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg
# !pip3 install --upgrade minerl
# !pip3 install pyvirtualdisplay
# !pip3 install pytorch
# !pip3 install -U colabgymrender

# %%
# !java -version
# Out:
# openjdk version "1.8.0_292"
# OpenJDK Runtime Environment (build 1.8.0_292-8u292-b10-0ubuntu1~18.04-b10)
# OpenJDK 64-Bit Server VM (build 25.292-b10, mixed mode)

# %% [markdown]
# # Download the data and code

# %%
# %env MINERL_DATA_ROOT=/content/data/

# !python3 -m minerl.data.download --environment "MineRLBasaltFindCave-v0"
# !ls $MINERL_DATA_ROOT
# Out:
# env: MINERL_DATA_ROOT=/content/data/
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'minerl.data.download' found in sys.modules after import of package 'minerl.data', but prior to execution of 'minerl.data.download'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2021-09-04 16:18:53 ddf421ea678c __main__[6101] INFO Downloading dataset for MineRLBasaltFindCave-v0 to /content/data/
# 2021-09-04 16:18:53 ddf421ea678c __main__[6101] INFO Fetching download hash ...
# 2021-09-04 16:18:53 ddf421ea678c __main__[6101] WARNING As of MineRL 0.3.0 automatic hash checking has been disabled.
# 2021-09-04 16:18:53 ddf421ea678c __main__[6101] INFO Starting download ...
# 2021-09-04 16:18:53 ddf421ea678c root[6101] DEBUG Choosing mirror ...
# 2021-09-04 16:18:53 ddf421ea678c root[6101] DEBUG Picked https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar ping=319.675ms
# 2021-09-04 16:18:53 ddf421ea678c root[6101] DEBUG Starting download at 0.0MB
# 2021-09-04 16:18:54 ddf421ea678c root[6101] DEBUG File size is 287.7MB
# Download: https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar:  99% 285.0/287.744 [00:09<00:00, 39.39MB/s]2021-09-04 16:19:03 ddf421ea678c root[6101] INFO Success - downloaded /content/data/download/v4/MineRLBasaltFindCave-v0.tar
# 2021-09-04 16:19:03 ddf421ea678c root[6101] INFO Extracting downloaded files - this may take some time
# Download: https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar: 100% 288.0/287.744 [00:09<00:00, 29.72MB/s]
# 2021-09-04 16:19:04 ddf421ea678c root[6101] INFO Success - extracted files to /content/data/
# download  MineRLBasaltFindCave-v0  VERSION

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/basalt-competition
# !pwd
# !ls $MINERL_DATA_ROOT
# Out:
# /content/gdrive/MyDrive/basalt-competition
# /content/gdrive/MyDrive/basalt-competition
# download  MineRLBasaltFindCave-v0  VERSION

# %% [markdown]
# # Run Training

# %%
# !python train_submission_code.py

# %%
# !python train_submission_code.py --preprocess-false

# %% [markdown]
# # Testing Subcomponents

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# !python generate_variable_demonstrations.py --zip-files
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Generating trajectory with epsilon=0.0
# Trajectory completed with 10 steps
# Trajectory Saved
# Generating trajectory with epsilon=1.0
# Trajectory completed with 10 steps
# Trajectory Saved
