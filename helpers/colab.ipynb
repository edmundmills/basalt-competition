# %% [markdown]
# # Setup

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg
# !pip3 install --upgrade minerl
# !pip3 install pyvirtualdisplay
# !pip3 install pytorch
# !pip3 install -U colabgymrender

# %%
# !java -version
# Out:
# openjdk version "1.8.0_292"
# OpenJDK Runtime Environment (build 1.8.0_292-8u292-b10-0ubuntu1~18.04-b10)
# OpenJDK 64-Bit Server VM (build 25.292-b10, mixed mode)

# %% [markdown]
# # Download the data and code

# %%
# %env MINERL_DATA_ROOT=/content/data/

# !python3 -m minerl.data.download --environment "MineRLBasaltFindCave-v0"
# !ls $MINERL_DATA_ROOT
# Out:
# env: MINERL_DATA_ROOT=/content/data/
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'minerl.data.download' found in sys.modules after import of package 'minerl.data', but prior to execution of 'minerl.data.download'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2021-09-07 17:40:13 a1b9cfd26c7d __main__[6103] INFO Downloading dataset for MineRLBasaltFindCave-v0 to /content/data/
# 2021-09-07 17:40:13 a1b9cfd26c7d __main__[6103] INFO Fetching download hash ...
# 2021-09-07 17:40:13 a1b9cfd26c7d __main__[6103] WARNING As of MineRL 0.3.0 automatic hash checking has been disabled.
# 2021-09-07 17:40:13 a1b9cfd26c7d __main__[6103] INFO Starting download ...
# 2021-09-07 17:40:13 a1b9cfd26c7d root[6103] DEBUG Choosing mirror ...
# 2021-09-07 17:40:14 a1b9cfd26c7d root[6103] DEBUG Picked https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar ping=158.48ms
# 2021-09-07 17:40:14 a1b9cfd26c7d root[6103] DEBUG Starting download at 0.0MB
# 2021-09-07 17:40:14 a1b9cfd26c7d root[6103] DEBUG File size is 287.7MB
# Download: https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar:  99% 286.0/287.744 [00:09<00:00, 40.05MB/s]2021-09-07 17:40:23 a1b9cfd26c7d root[6103] INFO Success - downloaded /content/data/download/v4/MineRLBasaltFindCave-v0.tar
# 2021-09-07 17:40:23 a1b9cfd26c7d root[6103] INFO Extracting downloaded files - this may take some time
# Download: https://minerl.s3.amazonaws.com/v4/MineRLBasaltFindCave-v0.tar: 100% 288.0/287.744 [00:09<00:00, 29.04MB/s]
# 2021-09-07 17:40:24 a1b9cfd26c7d root[6103] INFO Success - extracted files to /content/data/
# download  MineRLBasaltFindCave-v0  VERSION

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/basalt-competition
# !pwd
# !ls $MINERL_DATA_ROOT
# Out:
# /content/gdrive/MyDrive/basalt-competition
# /content/gdrive/MyDrive/basalt-competition
# download  MineRLBasaltFindCave-v0  VERSION

# %% [markdown]
# # Run Training

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# !python train_submission_code.py --train-critic-false

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# !python train_submission_code.py --preprocess-false --train-critic-false --debug-env
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Loading termination_critic_1631023395.pth as termination critic
# Traceback (most recent call last):
#   File "train_submission_code.py", line 97, in <module>
#     main()
#   File "train_submission_code.py", line 90, in main
#     bc_agent.train(env, run)
#   File "/content/gdrive/My Drive/basalt-competition/agents/soft_q.py", line 70, in train
#     action = self.get_action(current_obs)
#   File "/content/gdrive/My Drive/basalt-competition/agents/soft_q.py", line 51, in get_action
#     states = ObservationSpace.obs_to_states(obs)
#   File "/content/gdrive/My Drive/basalt-competition/helpers/environment.py", line 107, in obs_to_states
#     ObservationSpace.obs_to_frame_sequence(obs))
#   File "/content/gdrive/My Drive/basalt-competition/helpers/environment.py", line 75, in obs_to_frame_sequence
#     return obs['frame_sequence'].permute(0, 1, 4, 2, 3).float() / 255.0
# RuntimeError: number of dims don't match in permute

# %% [markdown]
# # Testing Subcomponents
