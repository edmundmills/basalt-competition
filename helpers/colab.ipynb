# %% [markdown]
# # Setup

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg
# !pip3 install --upgrade minerl
# !pip3 install pyvirtualdisplay
# !pip3 install pytorch
# !pip3 install -U colabgymrender
# !pip3 install wandb
# !pip install torch_tb_profiler
# !pip install hydra-core

# %%
# !pip3 install --upgrade minerl

# %% [markdown]
# # Download the data and code

# %%
# %env MINERL_DATA_ROOT=/content/data/
# !python3 -m minerl.data.download --environment "MineRLBasaltFindCave-v0"
# !python3 -m minerl.data.download --environment "MineRLBasaltBuildVillageHouse-v0"
# !python3 -m minerl.data.download --environment "MineRLTreechop-v0"
# !ls $MINERL_DATA_ROOT

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# %cd /content/gdrive/MyDrive/basalt-competition
# !pwd
# !ls $MINERL_DATA_ROOT

# %%
import wandb
wandb.login()

# %% [markdown]
# # IQ-Learn Online

# %%
# !python train_submission_code.py --pretrain \
algorithm=online_imitation loss_function=iqlearn \
pretraining.curiosity_pretraining_steps=10 \
pretraining.training_steps=100 pretraining.checkpoint_frequency=100 \
pretraining.batch_size=8 \
project_name=test --debug-env

# %%
# !python train_submission_code.py --pretrain \
algorithm=online_imitation loss_function=iqlearn \
project_name=pretraining

# %% [markdown]
# # IQ-Learn / SAC

# %%
# !python train_submission_code.py --wandb-false --debug-env algorithm=sac loss_function=iqlearn

# %% [markdown]
# # Obs space experiments

# %%
# !python bc_experiment.py

# %% [markdown]
# # Optimization

# %%
# !python -m cProfile -o output.pstats train_submission_code.py --profile --debug-env

# %%
# !pip install graphviz
# !pip install gprof2dot
# !gprof2dot -f pstats output.pstats | dot -Tpng -o output.png

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./logs
