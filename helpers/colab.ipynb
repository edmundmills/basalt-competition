# %% [markdown]
# # Setup

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg
# !pip3 install --upgrade minerl
# !pip3 install pyvirtualdisplay
# !pip3 install pytorch
# !pip3 install -U colabgymrender

# %%
# !java -version
# Out:
# openjdk version "1.8.0_292"
# OpenJDK Runtime Environment (build 1.8.0_292-8u292-b10-0ubuntu1~18.04-b10)
# OpenJDK 64-Bit Server VM (build 25.292-b10, mixed mode)

# %% [markdown]
# # Download the data and code

# %%
# %env MINERL_DATA_ROOT=/content/data/

# !python3 -m minerl.data.download --environment "MineRLBasaltFindCave-v0"
# !ls $MINERL_DATA_ROOT

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/basalt-competition
# !pwd
# !ls $MINERL_DATA_ROOT
# Out:
# /content/gdrive/MyDrive/basalt-competition
# /content/gdrive/MyDrive/basalt-competition
# download  MineRLBasaltFindCave-v0  VERSION

# %% [markdown]
# # Run Training

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# !python train_submission_code.py --train-critic-false --debug-env

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# !python train_submission_code.py --preprocess-false --train-critic-false
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Loading termination_critic_1631121471.pth as termination critic
# 2021-09-08 18:28:52 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] INFO Starting Minecraft process: ['/tmp/tmpns8jnz1o/Minecraft/launchClient.sh', '-port', '9034', '-env', '-runDir', '/tmp/tmpns8jnz1o/Minecraft/run']
# 2021-09-08 18:28:52 53d936a67774 process_watcher[11265] INFO Launhing process watcher daemonizer.
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'minerl.utils.process_watcher' found in sys.modules after import of package 'minerl.utils', but prior to execution of 'minerl.utils.process_watcher'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2021-09-08 18:28:53 53d936a67774 process_watcher[11265] INFO Process watcher daemonizer launched successfully.
# 2021-09-08 18:29:00 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] WARNING [18:29:00] [main/WARN]: The coremod com.microsoft.Malmo.OverclockingPlugin does not have a MCVersion annotation, it may cause issues with this version of Minecraft
# 2021-09-08 18:29:07 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] ERROR [18:29:07] [main/ERROR]: The binary patch set is missing. Either you are in a development environment, or things are not going to work!
# 2021-09-08 18:29:08 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] ERROR [18:29:08] [main/ERROR]: FML appears to be missing any signature data. This is not a good thing
# 2021-09-08 18:29:08 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] WARNING [18:29:08] [main/WARN]: Reference map 'mixins.malmo.refmap.json' for mixins.overclocking.malmomod.json could not be read. If this is a development environment you can ignore this message
# 2021-09-08 18:29:14 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] WARNING [18:29:14] [Client thread/WARN]: Skipping bad option: lastServer:
# 2021-09-08 18:29:32 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] WARNING [18:29:32] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpns8jnz1o/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# 2021-09-08 18:29:32 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] WARNING [18:29:32] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpns8jnz1o/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# 2021-09
53d936a67774 minerl.env.malmo.instance.74ef5e[11265] INFO Minecraft process ready
# 2021-09-08 18:29:44 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# 2021-09-08 18:29:44 53d936a67774 minerl.env.malmo[11265] INFO Logging output of Minecraft to ./logs/mc_34.log
# 2021-09-08 18:30:17 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] INFO [18:30:17] [Client thread/INFO]: [STDOUT]: [LOGTOPY] On Mac OSX Catalina make sure to install this OpenJDK 1.8.0_152-release-1056-b12, this prevents the NSDragRegions crash
# Training Starting
# Threw Snowball at step 27
# Termination reward: -0.94
# Trajectory completed at step 40
# 2021-09-08 18:30:37 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# Iteration 100. Loss: 2.58, 0.59 it/s
# Iteration 200. Loss: 3.10, 0.90 it/s
# Threw Snowball at step 241
# Termination reward: -0.68
# Trajectory completed at step 253
# 2021-09-08 18:35:16 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# Threw Snowball at step 254
# Termination reward: -0.75
# Trajectory completed at step 267
# 2021-09-08 18:36:05 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# 2021-09-08 18:36:05 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] ERROR [18:36:05] [Client thread/INFO]: [STDOUT]: STATE ERROR - multiple states in the queue.
# 2021-09-08 18:36:05 53d936a67774 minerl.env.malmo.instance.74ef5e[11265] ERROR [18:36:05] [Client thread/INFO]: [STDOUT]: STATE ERROR - multiple states in the queue.
# Iteration 300. Loss: 3.06, 0.57 it/s
# Threw Snowball at step 397
# Termination reward: -0.87
# Iteration 400. Loss: 2.72, 0.87 it/s
# Trajectory completed at step 410
# 2021-09-08 18:39:21 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# Iteration 500. Loss: 2.66, 0.72 it/s
# Iteration 600. Loss: 2.60, 0.90 it/s
# Iteration 700. Loss: 2.56, 0.92 it/s
# Iteration 800. Loss: 2.50, 0.91 it/s
# Iteration 900. Loss: 2.37, 0.91 it/s
# Iteration 1000. Loss: 2.38, 0.91 it/s
# Iteration 1100. Loss: 2.23, 0.91 it/s
# Iteration 1200. Loss: 2.23, 0.91 it/s
# Iteration 1300. Loss: 2.22, 0.90 it/s
# Iteration 1400. Loss: 2.16, 0.91 it/s
# Iteration 1500. Loss: 2.14, 0.91 it/s
# Threw Snowball at step 1582
# Termination reward: 0.27
# Trajectory completed at step 1595
# 2021-09-08 19:01:46 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# Iteration 1600. Loss: 2.06, 0.73 it/s
# Iteration 1700. Loss: 2.05, 0.90 it/s
# Iteration 1800. Loss: 2.01, 0.90 it/s
# Iteration 1900. Loss: 1.98, 0.91 it/s
# Iteration 2000. Loss: 1.95, 0.91 it/s
# Iteration 2100. Loss: 1.91, 0.90 it/s
# Iteration 2200. Loss: 1.81, 0.91 it/s
# Threw Snowball at step 2253
# Termination reward: 0.65
# Trajectory completed at step 2266
# 2021-09-08 19:14:44 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# Iteration 2300. Loss: 1.92, 0.72 it/s
# Iteration 2400. Loss: 1.85, 0.92 it/s
# Iteration 2500. Loss: 1.84, 0.91 it/s
# Iteration 2600. Loss: 1.83, 0.91 it/s
# Iteration 2700. Loss: 1.78, 0.92 it/s
# Threw Snowball at step 2740
# Termination reward: -0.81
# Threw Snowball at step 2744
# Termination reward: -0.69
# Trajectory completed at step 2753
# 2021-09-08 19:24:11 53d936a67774 minerl.env._multiagent[11265] INFO Attempting to quit: Malmo[None:74ef5e, proc=11280, addr=localhost:9034, locked=True]
# Iteration 2800. Loss: 1.77, 0.72 it/s
# Iteration 2900. Loss: 1.81, 0.91 it/s
# Iteration 3000. Loss: 1.74, 0.92 it/s
# Iteration 3100. Loss: 1.64, 0.93 it/s
# Iteration 3200. Loss: 1.70, 0.92 it/s
# Iteration 3300. Loss: 1.65, 0.91 it/s
# Iteration 3400. Loss: 1.72, 0.92 it/s
# Iteration 3500. Loss: 1.71, 0.92 it/s
# Iteration 3600. Loss: 1.71, 0.92 it/s
# Iteration 3700. Loss: 1.73, 0.92 it/s
# Iteration 3800. Loss: 1.69, 0.92 it/s
# Iteration 3900. Loss: 1.68, 0.92 it/s
# Iteration 4000. Loss: 1.71, 0.92 it/s
# Iteration 4100. Loss: 1.75, 0.92 it/s
# Iteration 4200. Loss: 1.74, 0.93 it/s
# Iteration 4300. Loss: 1.76, 0.93 it/s
# Iteration 4400. Loss: 1.70, 0.93 it/s
# Iteration 4500. Loss: 1.71, 0.93 it/s
# Iteration 4600. Loss: 1.67, 0.92 it/s
# Iteration 4700. Loss: 1.70, 0.92 it/s
# Iteration 4800. Loss: 1.70, 0.92 it/s
# Iteration 4900. Loss: 1.72, 0.93 it/s
# Training complete
# 2021-09-08 20:05:48 53d936a67774 process_watcher[11265] INFO About to reap process tree of 11280:launchClient.sh: i zombie, owner 11265, printing process tree status in termination order:
# 2021-09-08 20:05:48 53d936a67774 process_watcher[11265] INFO 	-11280:launchClient.sh: i zombie, owner 11265
# 2021-09-08 20:05:48 53d936a67774 process_watcher[11265] INFO Trying to SIGTERM 11280:launchClient.sh: i zombie, owner 11265
# 2021-09-08 20:05:48 53d936a67774 process_watcher[11265] INFO Process psutil.Popen(pid=11280, name='launchClient.sh', status='terminated', exitcode=0, started='18:28:52') terminated with exit code 0

# %% [markdown]
# # Testing Subcomponents
